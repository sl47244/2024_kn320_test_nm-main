# %% [markdown]
# ## Завдання на екзамен
# 1. У роботі №1, у проекті 2_project інсталювати бібліотеку matplotlib та виконати приклад з https://matplotlib.org/stable/users/getting_started/
# ![](install.png)
# - результат запуску на скріншоті
# ![](exam.png)
